# %%
import Cython
print(Cython.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import Cython
#       2 print(Cython.__version__)
#
# ModuleNotFoundError: No module named 'Cython'

# %%
import numpy as np

# %%
def z_to_a(z):
    return 1 / (1 + z)

def a_to_z(a):
    return 1 / a - 1

# %%
a_to_z(10e-3)
# Out:
# 99.0

# %%
zs = np.linspace(3,0,7)
zs
# Out:
# array([3. , 2.5, 2. , 1.5, 1. , 0.5, 0. ])

# %%
z_to_a(zs)
# Out:
# array([0.25      , 0.28571429, 0.33333333, 0.4       , 0.5       ,
#        0.66666667, 1.        ])
